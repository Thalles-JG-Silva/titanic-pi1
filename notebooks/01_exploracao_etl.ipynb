# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.data_preprocessing import load_data
from src.visualization import plot_survival_count, plot_age_distribution, plot_correlation

# %%
df = load_data("../data/train.csv")
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isna().sum()

# %%
plot_survival_count(df)

# %%
plot_age_distribution(df)

# %%
sns.countplot(data=df, x="Sex", hue="Survived")
plt.title("Sobrevivência por Sexo")
plt.show()

# %%
sns.countplot(data=df, x="Pclass", hue="Survived")
plt.title("Sobrevivência por Classe")
plt.show()

# %%
plot_correlation(df)

# %% [markdown]
# 📝 Resumo da Exploração Inicial (EDA)
#
# O dataset do Titanic contém 891 linhas e diversas colunas categóricas e numéricas relacionadas às características dos passageiros.
#
# Principais descobertas:
#
# Mulheres e crianças tiveram maior taxa de sobrevivência.
#
# Passageiros da 1ª classe sobreviveram muito mais do que os da 3ª.
#
# Idade tem valores faltantes e precisa ser tratada.
#
# Cabin possui muitos nulos → será descartada.
#
# Fare e Pclass têm correlação importante com a sobrevivência.
#
# Embarked tem poucos nulos e deve ser preenchido com a moda.
